# %%
#!/usr/bin/env python3
import multiprocessing
import os
import subprocess
import sys
import tempfile
import sympy as sp
import numpy as np
import pySecDec as psd

# %%
notebookdir = os.getcwd()

# %%
signmap = {
  sp.Symbol('x0'): 1,
  sp.Symbol('x1'): 1,
  sp.Symbol('x2'): 1,
  sp.Symbol('x3'): 1,
}

# %%
def needs_cdeform(name, Fpoly):
  poly = sp.sympify(str(Fpoly))
  terms = sp.Add.make_args(poly.expand())
  res = not all((t.subs(signmap) > 0) == True for t in terms)
  print(f'Needs-Contour-Deformation({name}, {poly}) = {res}')
  return res

# %%
def call(f):
  return f()

# %%
b1_propagators = [
  '(l1)^2-1',
  '(l1 - q1)^2-1',
  '(l1 + q2)^2-1',
  '(l1 - p1 + q2)^2-1'
]

# %%
b1_replacement_rules = [
  ('p1*p1', '-1/2*s12 + s13/2 + s23/2'),
  ('p1*q1', '-1/4*s12 - s13/4 + s23/4'),
  ('p1*q2', '-1/4*s12 + s13/4 - s23/4'),
  ('q1*q1', '0'),
  ('q1*q2', 's12/2'),
  ('q2*q2', '0')
]

# %%
b2_propagators = [
  '(l1)^2-1',
  '(l1 - q1)^2-1',
  '(l1 + p1 - q1)^2-1',
  '(l1 + q2)^2-1'
]

# %%
b2_replacement_rules = b1_replacement_rules

# %%
b3_propagators = [
  '(l1)^2-1',
  '(l1 - p1)^2-1',
  '(l1 - q1)^2-1',
  '(l1 - p1 + q2)^2-1'
]

# %%
b3_replacement_rules = b1_replacement_rules

# %%
def int_0_B1_0_1_1_0():
  li = psd.loop_integral.LoopIntegralFromPropagators(
    loop_momenta = ['l1'],
    external_momenta = ['p1','q1','q2'],
    propagators = b1_propagators,
    powerlist = [0,1,1,0],
    replacement_rules = b1_replacement_rules,
    dimensionality = '4-2*eps',
    regulators = ['eps']
  )
  return psd.LoopPackage(
    name = 'B1_0_1_1_0',
    loop_integral = li,
    real_parameters = ['s12', 's13', 's23'],
    additional_prefactor = 'I*2^(-4 + 2*eps)*pi^(-2 + eps)',
    decomposition_method = 'iterative',
    form_optimization_level = 4,
    form_work_space = '100M',
    form_threads = 1,
    contour_deformation = needs_cdeform('B1_0_1_1_0', li.F)
  )

# %%
def int_1_B1_0_1_1_1():
  li = psd.loop_integral.LoopIntegralFromPropagators(
    loop_momenta = ['l1'],
    external_momenta = ['p1','q1','q2'],
    propagators = b1_propagators,
    powerlist = [0,1,1,1],
    replacement_rules = b1_replacement_rules,
    dimensionality = '4-2*eps',
    regulators = ['eps']
  )
  return psd.LoopPackage(
    name = 'B1_0_1_1_1',
    loop_integral = li,
    real_parameters = ['s12', 's13', 's23'],
    additional_prefactor = 'I*2^(-4 + 2*eps)*pi^(-2 + eps)',
    decomposition_method = 'geometric_ku',
    form_optimization_level = 4,
    form_work_space = '100M',
    form_threads = 1,
    contour_deformation = needs_cdeform('B1_0_1_1_1', li.F)
  )

# %%
def int_2_B1_1_0_1_1():
  li = psd.loop_integral.LoopIntegralFromPropagators(
    loop_momenta = ['l1'],
    external_momenta = ['p1','q1','q2'],
    propagators = b1_propagators,
    powerlist = [1,0,1,1],
    replacement_rules = b1_replacement_rules,
    dimensionality = '4-2*eps',
    regulators = ['eps']
  )
  return psd.LoopPackage(
    name = 'B1_1_0_1_1',
    loop_integral = li,
    real_parameters = ['s12', 's13', 's23'],
    additional_prefactor = 'I*2^(-4 + 2*eps)*pi^(-2 + eps)',
    decomposition_method = 'geometric_ku',
    form_optimization_level = 4,
    form_work_space = '100M',
    form_threads = 1,
    contour_deformation = needs_cdeform('B1_1_0_1_1', li.F)
  )

# %%
def int_3_B1_1_1_0_1():
  li = psd.loop_integral.LoopIntegralFromPropagators(
    loop_momenta = ['l1'],
    external_momenta = ['p1','q1','q2'],
    propagators = b1_propagators,
    powerlist = [1,1,0,1],
    replacement_rules = b1_replacement_rules,
    dimensionality = '4-2*eps',
    regulators = ['eps']
  )
  return psd.LoopPackage(
    name = 'B1_1_1_0_1',
    loop_integral = li,
    real_parameters = ['s12', 's13', 's23'],
    additional_prefactor = 'I*2^(-4 + 2*eps)*pi^(-2 + eps)',
    decomposition_method = 'geometric_ku',
    form_optimization_level = 4,
    form_work_space = '100M',
    form_threads = 1,
    contour_deformation = needs_cdeform('B1_1_1_0_1', li.F)
  )

# %%
def int_4_B1_1_1_1_0():
  li = psd.loop_integral.LoopIntegralFromPropagators(
    loop_momenta = ['l1'],
    external_momenta = ['p1','q1','q2'],
    propagators = b1_propagators,
    powerlist = [1,1,1,0],
    replacement_rules = b1_replacement_rules,
    dimensionality = '4-2*eps',
    regulators = ['eps']
  )
  return psd.LoopPackage(
    name = 'B1_1_1_1_0',
    loop_integral = li,
    real_parameters = ['s12', 's13', 's23'],
    additional_prefactor = 'I*2^(-4 + 2*eps)*pi^(-2 + eps)',
    decomposition_method = 'geometric_ku',
    form_optimization_level = 4,
    form_work_space = '100M',
    form_threads = 1,
    contour_deformation = needs_cdeform('B1_1_1_1_0', li.F)
  )

# %%
def int_5_B1_1_1_1_1():
  li = psd.loop_integral.LoopIntegralFromPropagators(
    loop_momenta = ['l1'],
    external_momenta = ['p1','q1','q2'],
    propagators = b1_propagators,
    powerlist = [1,1,1,1],
    replacement_rules = b1_replacement_rules,
    dimensionality = '4-2*eps',
    regulators = ['eps']
  )
  return psd.LoopPackage(
    name = 'B1_1_1_1_1',
    loop_integral = li,
    real_parameters = ['s12', 's13', 's23'],
    additional_prefactor = 'I*2^(-4 + 2*eps)*pi^(-2 + eps)',
    decomposition_method = 'geometric_ku',
    form_optimization_level = 4,
    form_work_space = '100M',
    form_threads = 1,
    contour_deformation = needs_cdeform('B1_1_1_1_1', li.F)
  )

# %%
def int_6_B2_1_0_1_1():
  li = psd.loop_integral.LoopIntegralFromPropagators(
    loop_momenta = ['l1'],
    external_momenta = ['p1','q1','q2'],
    propagators = b2_propagators,
    powerlist = [1,0,1,1],
    replacement_rules = b2_replacement_rules,
    dimensionality = '4-2*eps',
    regulators = ['eps']
  )
  return psd.LoopPackage(
    name = 'B2_1_0_1_1',
    loop_integral = li,
    real_parameters = ['s12', 's13', 's23'],
    additional_prefactor = 'I*2^(-4 + 2*eps)*pi^(-2 + eps)',
    decomposition_method = 'geometric_ku',
    form_optimization_level = 4,
    form_work_space = '100M',
    form_threads = 1,
    contour_deformation = needs_cdeform('B2_1_0_1_1', li.F)
  )

# %%
def int_7_B2_1_1_1_0():
  li = psd.loop_integral.LoopIntegralFromPropagators(
    loop_momenta = ['l1'],
    external_momenta = ['p1','q1','q2'],
    propagators = b2_propagators,
    powerlist = [1,1,1,0],
    replacement_rules = b2_replacement_rules,
    dimensionality = '4-2*eps',
    regulators = ['eps']
  )
  return psd.LoopPackage(
    name = 'B2_1_1_1_0',
    loop_integral = li,
    real_parameters = ['s12', 's13', 's23'],
    additional_prefactor = 'I*2^(-4 + 2*eps)*pi^(-2 + eps)',
    decomposition_method = 'geometric_ku',
    form_optimization_level = 4,
    form_work_space = '100M',
    form_threads = 1,
    contour_deformation = needs_cdeform('B2_1_1_1_0', li.F)
  )

# %%
def int_8_B2_1_1_1_1():
  li = psd.loop_integral.LoopIntegralFromPropagators(
    loop_momenta = ['l1'],
    external_momenta = ['p1','q1','q2'],
    propagators = b2_propagators,
    powerlist = [1,1,1,1],
    replacement_rules = b2_replacement_rules,
    dimensionality = '4-2*eps',
    regulators = ['eps']
  )
  return psd.LoopPackage(
    name = 'B2_1_1_1_1',
    loop_integral = li,
    real_parameters = ['s12', 's13', 's23'],
    additional_prefactor = 'I*2^(-4 + 2*eps)*pi^(-2 + eps)',
    decomposition_method = 'geometric_ku',
    form_optimization_level = 4,
    form_work_space = '100M',
    form_threads = 1,
    contour_deformation = needs_cdeform('B2_1_1_1_1', li.F)
  )

# %%
def int_9_B3_1_1_1_1():
  li = psd.loop_integral.LoopIntegralFromPropagators(
    loop_momenta = ['l1'],
    external_momenta = ['p1','q1','q2'],
    propagators = b3_propagators,
    powerlist = [1,1,1,1],
    replacement_rules = b3_replacement_rules,
    dimensionality = '4-2*eps',
    regulators = ['eps']
  )
  return psd.LoopPackage(
    name = 'B3_1_1_1_1',
    loop_integral = li,
    real_parameters = ['s12', 's13', 's23'],
    additional_prefactor = 'I*2^(-4 + 2*eps)*pi^(-2 + eps)',
    decomposition_method = 'geometric_ku',
    form_optimization_level = 4,
    form_work_space = '100M',
    form_threads = 1,
    contour_deformation = needs_cdeform('B3_1_1_1_1', li.F)
  )

# %%
if __name__ == '__main__':
  # Always start in the directory this file resides in
  thisdir = os.path.dirname(sys.argv[0])
  if thisdir: os.chdir(os.path.dirname(sys.argv[0]))

# %%
  make_integrals = [
    int_0_B1_0_1_1_0,
    int_1_B1_0_1_1_1,
    int_2_B1_1_0_1_1,
    int_3_B1_1_1_0_1,
    int_4_B1_1_1_1_0,
    int_5_B1_1_1_1_1,
    int_6_B2_1_0_1_1,
    int_7_B2_1_1_1_0,
    int_8_B2_1_1_1_1,
    int_9_B3_1_1_1_1,
  ]

# %%
  coefficients = {
    "gH^2*gs^2*Na*Tf*flvsumt[1]": {
      0: "(32*eps*(s13 + s23))/((2 - 2*eps)*(3*s12 - s13 - s23))",
      1: "(-8*eps*s12*(3*s12 - 2*s13 - 2*s23)*(-8 + s13 + s23))/((1 - 2*eps)*(3*s12^2 - 2*s12*s13 - s13^2 - 2*s12*s23 + 2*s13*s23 - s23^2))",
      2: "((s12 - s13 + s23)*(48*s12^2 - 24*(4 - 2*eps)*s12^2 - 18*s12^3 + 6*(4 - 2*eps)*s12^3 - 32*s12*s13 + 16*(4 - 2*eps)*s12*s13 + 6*s12^2*s13 - (4 - 2*eps)*s12^2*s13 - 16*s13^2 + 8*(4 - 2*eps)*s13^2 + 10*s12*s13^2 - 4*(4 - 2*eps)*s12*s13^2 + 2*s13^3 - (4 - 2*eps)*s13^3 - 160*s12*s23 + 48*(4 - 2*eps)*s12*s23 + 6*s12^2*s23 - (4 - 2*eps)*s12^2*s23 + 32*s13*s23 - 16*(4 - 2*eps)*s13*s23 + 12*s12*s13*s23 - 4*(4 - 2*eps)*s12*s13*s23 - 2*s13^2*s23 + (4 - 2*eps)*s13^2*s23 - 16*s23^2 + 8*(4 - 2*eps)*s23^2 + 26*s12*s23^2 - 8*(4 - 2*eps)*s12*s23^2 - 2*s13*s23^2 + (4 - 2*eps)*s13*s23^2 + 2*s23^3 - (4 - 2*eps)*s23^3))/(2*(1 - 2*eps)*s12*(3*s12^2 - 2*s12*s13 - s13^2 - 2*s12*s23 + 2*s13*s23 - s23^2))",
      3: "-1/2*((3*s12 + s13 - s23)*(48*s12^2 - 24*(4 - 2*eps)*s12^2 - 18*s12^3 + 6*(4 - 2*eps)*s12^3 - 32*s12*s13 + 16*(4 - 2*eps)*s12*s13 + 6*s12^2*s13 - (4 - 2*eps)*s12^2*s13 - 16*s13^2 + 8*(4 - 2*eps)*s13^2 + 10*s12*s13^2 - 4*(4 - 2*eps)*s12*s13^2 + 2*s13^3 - (4 - 2*eps)*s13^3 - 160*s12*s23 + 48*(4 - 2*eps)*s12*s23 + 6*s12^2*s23 - (4 - 2*eps)*s12^2*s23 + 32*s13*s23 - 16*(4 - 2*eps)*s13*s23 + 12*s12*s13*s23 - 4*(4 - 2*eps)*s12*s13*s23 - 2*s13^2*s23 + (4 - 2*eps)*s13^2*s23 - 16*s23^2 + 8*(4 - 2*eps)*s23^2 + 26*s12*s23^2 - 8*(4 - 2*eps)*s12*s23^2 - 2*s13*s23^2 + (4 - 2*eps)*s13*s23^2 + 2*s23^3 - (4 - 2*eps)*s23^3))/((1 - 2*eps)*s12*(3*s12^2 - 2*s12*s13 - s13^2 - 2*s12*s23 + 2*s13*s23 - s23^2))",
      4: "(4*(54*s12^4 - 45*(4 - 2*eps)*s12^4 + 9*(4 - 2*eps)^2*s12^4 + 48*s12^2*s13 - 96*(4 - 2*eps)*s12^2*s13 + 24*(4 - 2*eps)^2*s12^2*s13 - 90*s12^3*s13 + 75*(4 - 2*eps)*s12^3*s13 - 15*(4 - 2*eps)^2*s12^3*s13 + 32*s12*s13^2 + 16*(4 - 2*eps)*s12*s13^2 - 8*(4 - 2*eps)^2*s12*s13^2 - 6*s12^2*s13^2 + 3*(4 - 2*eps)*s12^2*s13^2 + 48*s13^3 - 16*(4 - 2*eps)*s13^3 + 26*s12*s13^3 - 21*(4 - 2*eps)*s12*s13^3 + 4*(4 - 2*eps)^2*s12*s13^3 + 48*s12^2*s23 - 96*(4 - 2*eps)*s12^2*s23 + 24*(4 - 2*eps)^2*s12^2*s23 - 90*s12^3*s23 + 75*(4 - 2*eps)*s12^3*s23 - 15*(4 - 2*eps)^2*s12^3*s23 + 64*s12*s13*s23 + 32*(4 - 2*eps)*s12*s13*s23 - 16*(4 - 2*eps)^2*s12*s13*s23 + 60*s12^2*s13*s23 - 54*(4 - 2*eps)*s12^2*s13*s23 + 12*(4 - 2*eps)^2*s12^2*s13*s23 - 48*s13^2*s23 + 16*(4 - 2*eps)*s13^2*s23 + 6*s12*s13^2*s23 - 3*(4 - 2*eps)*s12*s13^2*s23 + 32*s12*s23^2 + 16*(4 - 2*eps)*s12*s23^2 - 8*(4 - 2*eps)^2*s12*s23^2 - 6*s12^2*s23^2 + 3*(4 - 2*eps)*s12^2*s23^2 - 48*s13*s23^2 + 16*(4 - 2*eps)*s13*s23^2 + 6*s12*s13*s23^2 - 3*(4 - 2*eps)*s12*s13*s23^2 + 48*s23^3 - 16*(4 - 2*eps)*s23^3 + 26*s12*s23^3 - 21*(4 - 2*eps)*s12*s23^3 + 4*(4 - 2*eps)^2*s12*s23^3))/((1 - 2*eps)*(2 - 2*eps)*(3*s12 - s13 - s23)*(3*s12^2 - 2*s12*s13 - s13^2 - 2*s12*s23 + 2*s13*s23 - s23^2))",
      5: "(-4*(-24*s12^2 - 18*s12^3 + 6*(4 - 2*eps)*s12^3 + 16*s12*s13 + 15*s12^2*s13 - 4*(4 - 2*eps)*s12^2*s13 + 8*s13^2 + 4*s12*s13^2 - 2*(4 - 2*eps)*s12*s13^2 - s13^3 + 16*s12*s23 + 15*s12^2*s23 - 4*(4 - 2*eps)*s12^2*s23 - 16*s13*s23 - 16*s12*s13*s23 + 4*(4 - 2*eps)*s12*s13*s23 + s13^2*s23 + 8*s23^2 - 28*s12*s23^2 + 6*(4 - 2*eps)*s12*s23^2 + s13*s23^2 + 4*s12*s13*s23^2 - (4 - 2*eps)*s12*s13*s23^2 - s23^3 + 4*s12*s23^3 - (4 - 2*eps)*s12*s23^3))/((1 - 2*eps)*(3*s12^2 - 2*s12*s13 - s13^2 - 2*s12*s23 + 2*s13*s23 - s23^2))",
      6: "-1/2*((3*s12 - s13 + s23)*(48*s12^2 - 24*(4 - 2*eps)*s12^2 - 18*s12^3 + 6*(4 - 2*eps)*s12^3 - 160*s12*s13 + 48*(4 - 2*eps)*s12*s13 + 6*s12^2*s13 - (4 - 2*eps)*s12^2*s13 - 16*s13^2 + 8*(4 - 2*eps)*s13^2 + 26*s12*s13^2 - 8*(4 - 2*eps)*s12*s13^2 + 2*s13^3 - (4 - 2*eps)*s13^3 - 32*s12*s23 + 16*(4 - 2*eps)*s12*s23 + 6*s12^2*s23 - (4 - 2*eps)*s12^2*s23 + 32*s13*s23 - 16*(4 - 2*eps)*s13*s23 + 12*s12*s13*s23 - 4*(4 - 2*eps)*s12*s13*s23 - 2*s13^2*s23 + (4 - 2*eps)*s13^2*s23 - 16*s23^2 + 8*(4 - 2*eps)*s23^2 + 10*s12*s23^2 - 4*(4 - 2*eps)*s12*s23^2 - 2*s13*s23^2 + (4 - 2*eps)*s13*s23^2 + 2*s23^3 - (4 - 2*eps)*s23^3))/((1 - 2*eps)*s12*(3*s12^2 - 2*s12*s13 - s13^2 - 2*s12*s23 + 2*s13*s23 - s23^2))",
      7: "((s12 + s13 - s23)*(48*s12^2 - 24*(4 - 2*eps)*s12^2 - 18*s12^3 + 6*(4 - 2*eps)*s12^3 - 160*s12*s13 + 48*(4 - 2*eps)*s12*s13 + 6*s12^2*s13 - (4 - 2*eps)*s12^2*s13 - 16*s13^2 + 8*(4 - 2*eps)*s13^2 + 26*s12*s13^2 - 8*(4 - 2*eps)*s12*s13^2 + 2*s13^3 - (4 - 2*eps)*s13^3 - 32*s12*s23 + 16*(4 - 2*eps)*s12*s23 + 6*s12^2*s23 - (4 - 2*eps)*s12^2*s23 + 32*s13*s23 - 16*(4 - 2*eps)*s13*s23 + 12*s12*s13*s23 - 4*(4 - 2*eps)*s12*s13*s23 - 2*s13^2*s23 + (4 - 2*eps)*s13^2*s23 - 16*s23^2 + 8*(4 - 2*eps)*s23^2 + 10*s12*s23^2 - 4*(4 - 2*eps)*s12*s23^2 - 2*s13*s23^2 + (4 - 2*eps)*s13*s23^2 + 2*s23^3 - (4 - 2*eps)*s23^3))/(2*(1 - 2*eps)*s12*(3*s12^2 - 2*s12*s13 - s13^2 - 2*s12*s23 + 2*s13*s23 - s23^2))",
      8: "(-4*(-24*s12^2 - 18*s12^3 + 6*(4 - 2*eps)*s12^3 + 16*s12*s13 + 15*s12^2*s13 - 4*(4 - 2*eps)*s12^2*s13 + 8*s13^2 - 28*s12*s13^2 + 6*(4 - 2*eps)*s12*s13^2 - s13^3 + 4*s12*s13^3 - (4 - 2*eps)*s12*s13^3 + 16*s12*s23 + 15*s12^2*s23 - 4*(4 - 2*eps)*s12^2*s23 - 16*s13*s23 - 16*s12*s13*s23 + 4*(4 - 2*eps)*s12*s13*s23 + s13^2*s23 + 4*s12*s13^2*s23 - (4 - 2*eps)*s12*s13^2*s23 + 8*s23^2 + 4*s12*s23^2 - 2*(4 - 2*eps)*s12*s23^2 + s13*s23^2 - s23^3))/((1 - 2*eps)*(3*s12^2 - 2*s12*s13 - s13^2 - 2*s12*s23 + 2*s13*s23 - s23^2))",
      9: "-1/4*(-128*s12 - 48*s12^2 + 8*(4 - 2*eps)*s12^2 - 18*s12^3 + 6*(4 - 2*eps)*s12^3 - 16*s12*s13 + 16*(4 - 2*eps)*s12*s13 + 6*s12^2*s13 - (4 - 2*eps)*s12^2*s13 - 16*s13^2 + 8*(4 - 2*eps)*s13^2 + 10*s12*s13^2 - 4*(4 - 2*eps)*s12*s13^2 + 2*s13^3 - (4 - 2*eps)*s13^3 - 16*s12*s23 + 16*(4 - 2*eps)*s12*s23 + 6*s12^2*s23 - (4 - 2*eps)*s12^2*s23 + 32*s13*s23 - 16*(4 - 2*eps)*s13*s23 - 4*s12*s13*s23 - 2*s13^2*s23 + (4 - 2*eps)*s13^2*s23 - 16*s23^2 + 8*(4 - 2*eps)*s23^2 + 10*s12*s23^2 - 4*(4 - 2*eps)*s12*s23^2 - 2*s13*s23^2 + (4 - 2*eps)*s13*s23^2 + 2*s23^3 - (4 - 2*eps)*s23^3)/((1 - 2*eps)*s12)",
    },
  }
  try:
    nthreads = int(os.environ['THREADS'])
  except KeyError:
    try:
      nthreads = len(os.sched_getaffinity(0))
    except AttributeError:
      nthreads = os.cpu_count()
  if nthreads > 1:
    with multiprocessing.Pool(nthreads) as pool:
      integrals = pool.map(call, make_integrals)
  else:
    integrals = [f() for f in make_integrals]
  subprocess.check_call(['rm', '-rf', 'disteval'])
  cwd = os.getcwd()
  with tempfile.TemporaryDirectory(prefix='psd') as tmp:
    os.chdir(tmp)
    psd.sum_package('sum',
      integrals,
      coefficients = coefficients,
      regulators = ['eps'],
      requested_orders = [0],
      real_parameters = ['s12', 's13', 's23'],
      processes = nthreads,
    )
    subprocess.check_call(['make', '-C', 'sum', '-j', str(nthreads), 'disteval.done'])
    subprocess.check_call(['cp', '-a', 'sum/disteval', cwd])
    subprocess.check_call(['rm', '-rf', 'sum'])
# Out:
# Needs-Contour-Deformation(B1_0_1_1_0, x1**2 + x1*x2*(2 - s12) + x2**2) = True
# Needs-Contour-Deformation(B1_1_1_0_1, x0**2 + 2*x0*x1 + x0*x3*(2 - s23) + x1**2 + x1*x3*(-3*s12/2 - s13/2 - s23/2 + 2) + x3**2) = True
# Needs-Contour-Deformation(B1_1_0_1_1, x0**2 + 2*x0*x2 + x0*x3*(2 - s23) + x2**2 + x2*x3*(s12/2 - s13/2 - s23/2 + 2) + x3**2) = True
# Needs-Contour-Deformation(B1_0_1_1_1, x1**2 + x1*x2*(2 - s12) + x1*x3*(-3*s12/2 - s13/2 - s23/2 + 2) + x2**2 + x2*x3*(s12/2 - s13/2 - s23/2 + 2) + x3**2) = True
# Needs-Contour-Deformation(B1_1_1_1_0, x0**2 + 2*x0*x1 + 2*x0*x2 + x1**2 + x1*x2*(2 - s12) + x2**2) = True
# Needs-Contour-Deformation(B1_1_1_1_1, x0**2 + 2*x0*x1 + 2*x0*x2 + x0*x3*(2 - s23) + x1**2 + x1*x2*(2 - s12) + x1*x3*(-3*s12/2 - s13/2 - s23/2 + 2) + x2**2 + x2*x3*(s12/2 - s13/2 - s23/2 + 2) + x3**2) = True
# Needs-Contour-Deformation(B2_1_0_1_1, x0**2 + x0*x2*(2 - s13) + 2*x0*x3 + x2**2 + x2*x3*(-3*s12/2 - s13/2 - s23/2 + 2) + x3**2) = TrueNeeds-Contour-Deformation(B2_1_1_1_0, x0**2 + 2*x0*x1 + x0*x2*(2 - s13) + x1**2 + x1*x2*(s12/2 - s13/2 - s23/2 + 2) + x2**2) = True
#
# Needs-Contour-Deformation(B2_1_1_1_1, x0**2 + 2*x0*x1 + x0*x2*(2 - s13) + 2*x0*x3 + x1**2 + x1*x2*(s12/2 - s13/2 - s23/2 + 2) + x1*x3*(2 - s12) + x2**2 + x2*x3*(-3*s12/2 - s13/2 - s23/2 + 2) + x3**2) = True
# Needs-Contour-Deformation(B3_1_1_1_1, x0**2 + x0*x1*(s12/2 - s13/2 - s23/2 + 2) + 2*x0*x2 + x0*x3*(2 - s23) + x1**2 + x1*x2*(2 - s13) + 2*x1*x3 + x2**2 + x2*x3*(-3*s12/2 - s13/2 - s23/2 + 2) + x3**2) = True
# running "sum_package" for sum
# running "make_package" for "B1_1_1_0_1"running "make_package" for "B1_0_1_1_0"running "make_package" for "B1_0_1_1_1"
# running "make_package" for "B1_1_0_1_1"
#
#
# number of primary sectors before symmetry finding: 2
# number of primary sectors before symmetry finding:number of primary sectors before symmetry finding:  number of primary sectors after symmetry finding (iterative):33 1
#
# number of primary sectors after symmetry finding (light Pak):
#  1
# number of primary sectors after symmetry finding (full Pak): 1
# computing Jacobian determinant for primary sector 0
# total number sectors before symmetry finding:number of primary sectors after symmetry finding (iterative): number of primary sectors after symmetry finding (iterative):1 3
#
#  3total number sectors after symmetry finding (iterative):
#  1number of primary sectors after symmetry finding (light Pak):
#  number of primary sectors after symmetry finding (light Pak):total number sectors after symmetry finding (light Pak):3number of primary sectors before symmetry finding:
# 1  33
#
# total number sectors after symmetry finding (full Pak):number of primary sectors after symmetry finding (full Pak):
#   31
#
# computing Jacobian determinant for primary sectorwriting FORM files for sector  10
# number of primary sectors after symmetry finding (full Pak):number of primary sectors after symmetry finding (iterative):
#  3
#  3
# number of primary sectors after symmetry finding (light Pak):computing Jacobian determinant for primary sector 3
# 0
# number of primary sectors after symmetry finding (full Pak): 3
# total number sectors before symmetry finding: computing Jacobian determinant for primary sector 3
# 0
# total number sectors before symmetry finding: total number sectors after symmetry finding (iterative): 3
# 3
# total number sectors after symmetry finding (light Pak): total number sectors after symmetry finding (iterative):3
# total number sectors before symmetry finding:  33
#
# total number sectors after symmetry finding (full Pak):total number sectors after symmetry finding (iterative):total number sectors after symmetry finding (light Pak): 3
#   33total number sectors after symmetry finding (full Pak):
#
# writing FORM files for sector3 1
#
# writing FORM files for sector total number sectors after symmetry finding (light Pak): 13
#
# total number sectors after symmetry finding (full Pak): 3
# writing FORM files for sector 1
# expanding the prefactor 2**(2*eps - 4)*I*pi**(eps - 2)*gamma(eps) (regulators: [eps] , orders: [0]writing FORM files for sector 2
#  )
# writing FORM files for sector  + (I/(16*pi**2))*eps**-1 + (-EulerGamma*I/(16*pi**2) + I*log(pi)/(16*pi**2) + I*log(2)/(8*pi**2))writing FORM files for sector
# 2
# 3
# writing FORM files for sector 3
# expanding the prefactor writing FORM files for sector-2**(2*eps - 4)*I*pi**(eps - 2)*gamma(eps + 1) (regulators: "B1_0_1_1_0" done [eps] , orders:2
#
# [0] )
#  + (-I/(16*pi**2))running "make_package" for "B1_1_1_1_0"
#
# expanding the prefactor -2**(2*eps - 4)*I*pi**(eps - 2)*gamma(eps + 1) "B1_1_0_1_1" done(regulators: [eps] , orders:
#  writing FORM files for sector[0]  running "make_package" for "B1_1_1_1_1"
# 3)
#
#  + (-I/(16*pi**2))
# "B1_0_1_1_1" done
# running "make_package" for "B2_1_0_1_1"
# number of primary sectors before symmetry finding: expanding the prefactor3
#  -2**(2*eps - 4)*I*pi**(eps - 2)*gamma(eps + 1) (regulators:number of primary sectors after symmetry finding (iterative): [eps]  2
# , orders: number of primary sectors after symmetry finding (light Pak):number of primary sectors before symmetry finding:[0]   4
# )2
#
# number of primary sectors after symmetry finding (iterative): 4
#  + (-I/(16*pi**2))number of primary sectors after symmetry finding (full Pak): 2
#
# computing Jacobian determinant for primary sector number of primary sectors after symmetry finding (light Pak):0"B1_1_1_0_1" done number of primary sectors before symmetry finding:
#
#  3
# 4running "make_package" for "B2_1_1_1_0"
# total number sectors before symmetry finding:
#  number of primary sectors after symmetry finding (iterative):2
#  3total number sectors after symmetry finding (iterative):
#  number of primary sectors after symmetry finding (full Pak):number of primary sectors after symmetry finding (light Pak): 4
# 2computing Jacobian determinant for primary sector 0
#
#  3total number sectors after symmetry finding (light Pak):
# 2
# number of primary sectors after symmetry finding (full Pak): 3total number sectors after symmetry finding (full Pak):
# computing Jacobian determinant for primary sector  0
# 2
# writing FORM files for sector 1
# number of primary sectors before symmetry finding: 3total number sectors before symmetry finding:
#  4total number sectors before symmetry finding:number of primary sectors after symmetry finding (iterative):
#  3
# 3
# total number sectors after symmetry finding (iterative):number of primary sectors after symmetry finding (light Pak):writing FORM files for sector   2
# 43total number sectors after symmetry finding (iterative):
#
# 3
# number of primary sectors after symmetry finding (full Pak):total number sectors after symmetry finding (light Pak): 3
#  computing Jacobian determinant for primary sector4 total number sectors after symmetry finding (light Pak): 0expanding the prefactor3
#
#
# -2**(2*eps - 4)*I*pi**(eps - 2)*gamma(eps + 1) total number sectors after symmetry finding (full Pak):total number sectors after symmetry finding (full Pak):(regulators: 4
# 3[eps]writing FORM files for sector
# writing FORM files for sector, orders:  1
# 1
#  total number sectors before symmetry finding:[0]  3)
#
# total number sectors after symmetry finding (iterative):writing FORM files for sector  + (-I/(16*pi**2))3
# 2
# "B1_1_1_1_0" done
# total number sectors after symmetry finding (light Pak):
# running "make_package" for "B2_1_1_1_1"
# 3writing FORM files for sector
# 2
# writing FORM files for sectortotal number sectors after symmetry finding (full Pak):  33
#
# writing FORM files for sector 1
# writing FORM files for sector 3
# number of primary sectors before symmetry finding: 4
# expanding the prefactor number of primary sectors after symmetry finding (iterative):-2**(2*eps - 4)*I*pi**(eps - 2)*gamma(eps + 1) writing FORM files for sector 4 (regulators:
# 2
#  number of primary sectors after symmetry finding (light Pak):[eps] 4 , orders:writing FORM files for sector
# [0]4
#  )
# number of primary sectors after symmetry finding (full Pak):  + (-I/(16*pi**2))writing FORM files for sector
# 34
#
# computing Jacobian determinant for primary sector "B2_1_0_1_1" done0
#
# running "make_package" for "B3_1_1_1_1"expanding the prefactor
#  2**(2*eps - 4)*I*pi**(eps - 2)*gamma(eps + 2) (regulators:expanding the prefactor  [eps]-2**(2*eps - 4)*I*pi**(eps - 2)*gamma(eps + 1)  (regulators:, orders:  [eps][0] total number sectors before symmetry finding: ) , orders:
# 4
#  [0] )
# number of primary sectors before symmetry finding: + (I/(16*pi**2))  + (-I/(16*pi**2))4
#
#
# "B1_1_1_1_1" donetotal number sectors after symmetry finding (iterative):"B2_1_1_1_0" done
#
#  4
# number of primary sectors after symmetry finding (iterative):total number sectors after symmetry finding (light Pak):  4
# 4
# total number sectors after symmetry finding (full Pak): number of primary sectors after symmetry finding (light Pak): 44
#
# writing FORM files for sector 1
# number of primary sectors after symmetry finding (full Pak): 4
# computing Jacobian determinant for primary sector 0
# writing FORM files for sector 2
# total number sectors before symmetry finding: 4
# total number sectors after symmetry finding (iterative): 4
# writing FORM files for sector 3
# total number sectors after symmetry finding (light Pak): 4
# total number sectors after symmetry finding (full Pak): 4
# writing FORM files for sector 1
# writing FORM files for sector 4
# expanding the prefactorwriting FORM files for sector  22**(2*eps - 4)*I*pi**(eps - 2)*gamma(eps + 2)
#  (regulators: [eps] , orders: [0] )
#  + (I/(16*pi**2))
# writing FORM files for sector"B2_1_1_1_1" done
# 3
# writing FORM files for sector 4
# expanding the prefactor 2**(2*eps - 4)*I*pi**(eps - 2)*gamma(eps + 2) (regulators: [eps] , orders: [0] )
#  + (I/(16*pi**2))
# "B3_1_1_1_1" done
# make: Entering directory '/home/formswap/jasons/psd5kkjfwyb/sum'
# ln -f B1_0_1_1_0/disteval/B1_0_1_1_0.json disteval/B1_0_1_1_0.json
# make -C B1_0_1_1_0/ disteval.done
# ln -f B1_0_1_1_1/disteval/B1_0_1_1_1.json disteval/B1_0_1_1_1.json
# make -C B1_0_1_1_1/ disteval.done
# ln -f B1_1_0_1_1/disteval/B1_1_0_1_1.json disteval/B1_1_0_1_1.json
# make[1]: Entering directory '/home/formswap/jasons/psd5kkjfwyb/sum/B1_0_1_1_0'
# make -C B1_1_0_1_1/ disteval.done
# g++ -c -o distsrc/builtin.o -fPIC -std=c++14 -O3 -funsafe-math-optimizations  distsrc/builtin.cpp
# make[1]: Entering directory '/home/formswap/jasons/psd5kkjfwyb/sum/B1_0_1_1_1'
# make[1]: Entering directory '/home/formswap/jasons/psd5kkjfwyb/sum/B1_1_0_1_1'
# cd codegen && /export/pc/bin/python3.10 '/users/tp/jasons/.local/lib/python3.10/site-packages/pySecDecContrib/bin/formwrapper' "/users/tp/jasons/.local/lib/python3.10/site-packages/pySecDecContrib/bin/form" -M -w1 -D optimizationLevel=4 -p '/users/tp/jasons/.local/lib/python3.10/site-packages/pySecDecContrib/lib' -D sectorID=3 '/users/tp/jasons/.local/lib/python3.10/site-packages/pySecDecContrib/lib/write_integrand.frm'
# cd codegen && /export/pc/bin/python3.10 '/users/tp/jasons/.local/lib/python3.10/site-packages/pySecDecContrib/bin/formwrapper' "/users/tp/jasons/.local/lib/python3.10/site-packages/pySecDecContrib/bin/form" -M -w1 -D optimizationLevel=4 -p '/users/tp/jasons/.local/lib/python3.10/site-packages/pySecDecContrib/lib' -D sectorID=3 '/users/tp/jasons/.local/lib/python3.10/site-packages/pySecDecContrib/lib/write_integrand.frm'
# cd codegen && /export/pc/bin/python3.10 '/users/tp/jasons/.local/lib/python3.10/site-packages/pySecDecContrib/bin/formwrapper' "/users/tp/jasons/.local/lib/python3.10/site-packages/pySecDecContrib/bin/form" -M -w1 -D optimizationLevel=4 -p '/users/tp/jasons/.local/lib/python3.10/site-packages/pySecDecContrib/lib' -D sectorID=1 '/users/tp/jasons/.local/lib/python3.10/site-packages/pySecDecContrib/lib/write_integrand.frm'
# FORM 4.3.0 (Nov 12 2022, v4.3.0) 64-bits         Run: Thu Dec 21 14:29:35 2023
#     #-
#   0.02 sec out of 0.03 sec
# /export/pc/bin/python3.10 '/users/tp/jasons/.local/lib/python3.10/site-packages/pySecDecContrib/bin/export_sector' codegen/sector3.info ./
# touch codegen/sector3.done
# FORM 4.3.0 (Nov 12 2022, v4.3.0) 64-bits         Run: Thu Dec 21 14:29:35 2023
#     #-
#   0.09 sec out of 0.11 sec
# /export/pc/bin/python3.10 '/users/tp/jasons/.local/lib/python3.10/site-packages/pySecDecContrib/bin/export_sector' codegen/sector1.info ./
# cd codegen && /export/pc/bin/python3.10 '/users/tp/jasons/.local/lib/python3.10/site-packages/pySecDecContrib/bin/formwrapper' "/users/tp/jasons/.local/lib/python3.10/site-packages/pySecDecContrib/bin/form" -M -w1 -D optimizationLevel=4 -p '/users/tp/jasons/.local/lib/python3.10/site-packages/pySecDecContrib/lib' -D sectorID=2 '/users/tp/jasons/.local/lib/python3.10/site-packages/pySecDecContrib/lib/write_integrand.frm'
# touch codegen/sector1.done
# g++ -c -o distsrc/sector_1_0.o -fPIC -std=c++14 -O3 -funsafe-math-optimizations  distsrc/sector_1_0.cpp
# FORM 4.3.0 (Nov 12 2022, v4.3.0) 64-bits         Run: Thu Dec 21 14:29:35 2023
#     #-
#   0.02 sec out of 0.02 sec
# /export/pc/bin/python3.10 '/users/tp/jasons/.local/lib/python3.10/site-packages/pySecDecContrib/bin/export_sector' codegen/sector2.info ./
# touch codegen/sector2.done
# cd codegen && /export/pc/bin/python3.10 '/users/tp/jasons/.local/lib/python3.10/site-packages/pySecDecContrib/bin/formwrapper' "/users/tp/jasons/.local/lib/python3.10/site-packages/pySecDecContrib/bin/form" -M -w1 -D optimizationLevel=4 -p '/users/tp/jasons/.local/lib/python3.10/site-packages/pySecDecContrib/lib' -D sectorID=1 '/users/tp/jasons/.local/lib/python3.10/site-packages/pySecDecContrib/lib/write_integrand.frm'
# FORM 4.3.0 (Nov 12 2022, v4.3.0) 64-bits         Run: Thu Dec 21 14:29:34 2023
#     #-
#   0.29 sec out of 0.32 sec
# /export/pc/bin/python3.10 '/users/tp/jasons/.local/lib/python3.10/site-packages/pySecDecContrib/bin/export_sector' codegen/sector3.info ./
# FORM 4.3.0 (Nov 12 2022, v4.3.0) 64-bits         Run: Thu Dec 21 14:29:35 2023
#     #-
#   0.02 sec out of 0.02 sec
# /export/pc/bin/python3.10 '/users/tp/jasons/.local/lib/python3.10/site-packages/pySecDecContrib/bin/export_sector' codegen/sector1.info ./
# touch codegen/sector1.done
# g++ -c -o distsrc/builtin.o -fPIC -std=c++14 -O3 -funsafe-math-optimizations  distsrc/builtin.cpp
# touch codegen/sector3.done
# cd codegen && /export/pc/bin/python3.10 '/users/tp/jasons/.local/lib/python3.10/site-packages/pySecDecContrib/bin/formwrapper' "/users/tp/jasons/.local/lib/python3.10/site-packages/pySecDecContrib/bin/form" -M -w1 -D optimizationLevel=4 -p '/users/tp/jasons/.local/lib/python3.10/site-packages/pySecDecContrib/lib' -D sectorID=2 '/users/tp/jasons/.local/lib/python3.10/site-packages/pySecDecContrib/lib/write_integrand.frm'
# FORM 4.3.0 (Nov 12 2022, v4.3.0) 64-bits         Run: Thu Dec 21 14:29:35 2023
#     #-
#   0.28 sec out of 0.28 sec
# /export/pc/bin/python3.10 '/users/tp/jasons/.local/lib/python3.10/site-packages/pySecDecContrib/bin/export_sector' codegen/sector2.info ./
# touch codegen/sector2.done
# cd codegen && /export/pc/bin/python3.10 '/users/tp/jasons/.local/lib/python3.10/site-packages/pySecDecContrib/bin/formwrapper' "/users/tp/jasons/.local/lib/python3.10/site-packages/pySecDecContrib/bin/form" -M -w1 -D optimizationLevel=4 -p '/users/tp/jasons/.local/lib/python3.10/site-packages/pySecDecContrib/lib' -D sectorID=1 '/users/tp/jasons/.local/lib/python3.10/site-packages/pySecDecContrib/lib/write_integrand.frm'
# FORM 4.3.0 (Nov 12 2022, v4.3.0) 64-bits         Run: Thu Dec 21 14:29:35 2023
#     #-
#   0.26 sec out of 0.26 sec
# /export/pc/bin/python3.10 '/users/tp/jasons/.local/lib/python3.10/site-packages/pySecDecContrib/bin/export_sector' codegen/sector1.info ./
# touch codegen/sector1.done
# g++ -c -o distsrc/builtin.o -fPIC -std=c++14 -O3 -funsafe-math-optimizations  distsrc/builtin.cpp
# g++ -c -o distsrc/sector_3_n1.o -fPIC -std=c++14 -O3 -funsafe-math-optimizations  distsrc/sector_3_n1.cpp
# g++ -c -o distsrc/sector_3_0.o -fPIC -std=c++14 -O3 -funsafe-math-optimizations  distsrc/sector_3_0.cpp
# g++ -shared -o disteval/builtin.so distsrc/builtin.o
# g++ -shared -o disteval/B1_0_1_1_0.so @disteval/B1_0_1_1_0.so.sourcelist
# g++ -c -o distsrc/sector_2_n1.o -fPIC -std=c++14 -O3 -funsafe-math-optimizations  distsrc/sector_2_n1.cpp
# g++ -c -o distsrc/sector_1_n1.o -fPIC -std=c++14 -O3 -funsafe-math-optimizations  distsrc/sector_1_n1.cpp
# date >disteval.done
# make[1]: Leaving directory '/home/formswap/jasons/psd5kkjfwyb/sum/B1_0_1_1_0'
# ln -f B1_1_1_0_1/disteval/B1_1_1_0_1.json disteval/B1_1_1_0_1.json
# make -C B1_1_1_0_1/ disteval.done
# make[1]: Entering directory '/home/formswap/jasons/psd5kkjfwyb/sum/B1_1_1_0_1'
# g++ -c -o distsrc/sector_2_0.o -fPIC -std=c++14 -O3 -funsafe-math-optimizations  distsrc/sector_2_0.cpp
# cd codegen && /export/pc/bin/python3.10 '/users/tp/jasons/.local/lib/python3.10/site-packages/pySecDecContrib/bin/formwrapper' "/users/tp/jasons/.local/lib/python3.10/site-packages/pySecDecContrib/bin/form" -M -w1 -D optimizationLevel=4 -p '/users/tp/jasons/.local/lib/python3.10/site-packages/pySecDecContrib/lib' -D sectorID=3 '/users/tp/jasons/.local/lib/python3.10/site-packages/pySecDecContrib/lib/write_integrand.frm'
# g++ -shared -o disteval/builtin.so distsrc/builtin.o
# cd codegen && /export/pc/bin/python3.10 '/users/tp/jasons/.local/lib/python3.10/site-packages/pySecDecContrib/bin/formwrapper' "/users/tp/jasons/.local/lib/python3.10/site-packages/pySecDecContrib/bin/form" -M -w1 -D optimizationLevel=4 -p '/users/tp/jasons/.local/lib/python3.10/site-packages/pySecDecContrib/lib' -D sectorID=2 '/users/tp/jasons/.local/lib/python3.10/site-packages/pySecDecContrib/lib/write_integrand.frm'
# g++ -shared -o disteval/B1_0_1_1_1.so @disteval/B1_0_1_1_1.so.sourcelist
# date >disteval.done
# make[1]: Leaving directory '/home/formswap/jasons/psd5kkjfwyb/sum/B1_0_1_1_1'
# ln -f B1_1_1_1_0/disteval/B1_1_1_1_0.json disteval/B1_1_1_1_0.json
# make -C B1_1_1_1_0/ disteval.done
# make[1]: Entering directory '/home/formswap/jasons/psd5kkjfwyb/sum/B1_1_1_1_0'
# cd codegen && /export/pc/bin/python3.10 '/users/tp/jasons/.local/lib/python3.10/site-packages/pySecDecContrib/bin/formwrapper' "/users/tp/jasons/.local/lib/python3.10/site-packages/pySecDecContrib/bin/form" -M -w1 -D optimizationLevel=4 -p '/users/tp/jasons/.local/lib/python3.10/site-packages/pySecDecContrib/lib' -D sectorID=2 '/users/tp/jasons/.local/lib/python3.10/site-packages/pySecDecContrib/lib/write_integrand.frm'
# FORM 4.3.0 (Nov 12 2022, v4.3.0) 64-bits         Run: Thu Dec 21 14:29:38 2023
#     #-
#   0.29 sec out of 0.39 sec
# /export/pc/bin/python3.10 '/users/tp/jasons/.local/lib/python3.10/site-packages/pySecDecContrib/bin/export_sector' codegen/sector3.info ./
# touch codegen/sector3.done
# cd codegen && /export/pc/bin/python3.10 '/users/tp/jasons/.local/lib/python3.10/site-packages/pySecDecContrib/bin/formwrapper' "/users/tp/jasons/.local/lib/python3.10/site-packages/pySecDecContrib/bin/form" -M -w1 -D optimizationLevel=4 -p '/users/tp/jasons/.local/lib/python3.10/site-packages/pySecDecContrib/lib' -D sectorID=1 '/users/tp/jasons/.local/lib/python3.10/site-packages/pySecDecContrib/lib/write_integrand.frm'
# g++ -c -o distsrc/sector_1_0.o -fPIC -std=c++14 -O3 -funsafe-math-optimizations  distsrc/sector_1_0.cpp
# FORM 4.3.0 (Nov 12 2022, v4.3.0) 64-bits         Run: Thu Dec 21 14:29:38 2023
#     #-
#   0.21 sec out of 0.23 sec
# /export/pc/bin/python3.10 '/users/tp/jasons/.local/lib/python3.10/site-packages/pySecDecContrib/bin/export_sector' codegen/sector2.info ./
# touch codegen/sector2.done
# cd codegen && /export/pc/bin/python3.10 '/users/tp/jasons/.local/lib/python3.10/site-packages/pySecDecContrib/bin/formwrapper' "/users/tp/jasons/.local/lib/python3.10/site-packages/pySecDecContrib/bin/form" -M -w1 -D optimizationLevel=4 -p '/users/tp/jasons/.local/lib/python3.10/site-packages/pySecDecContrib/lib' -D sectorID=1 '/users/tp/jasons/.local/lib/python3.10/site-packages/pySecDecContrib/lib/write_integrand.frm'
# FORM 4.3.0 (Nov 12 2022, v4.3.0) 64-bits         Run: Thu Dec 21 14:29:38 2023
#     #-
#   0.28 sec out of 0.46 sec
# /export/pc/bin/python3.10 '/users/tp/jasons/.local/lib/python3.10/site-packages/pySecDecContrib/bin/export_sector' codegen/sector2.info ./
# touch codegen/sector2.done
# g++ -shared -o disteval/builtin.so distsrc/builtin.o
# FORM 4.3.0 (Nov 12 2022, v4.3.0) 64-bits         Run: Thu Dec 21 14:29:38 2023
#     #-
#   0.23 sec out of 0.27 sec
# /export/pc/bin/python3.10 '/users/tp/jasons/.local/lib/python3.10/site-packages/pySecDecContrib/bin/export_sector' codegen/sector1.info ./
# g++ -c -o distsrc/builtin.o -fPIC -std=c++14 -O3 -funsafe-math-optimizations  distsrc/builtin.cpp
# touch codegen/sector1.done
# g++ -c -o distsrc/builtin.o -fPIC -std=c++14 -O3 -funsafe-math-optimizations  distsrc/builtin.cpp
# FORM 4.3.0 (Nov 12 2022, v4.3.0) 64-bits         Run: Thu Dec 21 14:29:39 2023
#     #-
#   0.27 sec out of 0.37 sec
# /export/pc/bin/python3.10 '/users/tp/jasons/.local/lib/python3.10/site-packages/pySecDecContrib/bin/export_sector' codegen/sector1.info ./
# g++ -shared -o disteval/B1_1_0_1_1.so @disteval/B1_1_0_1_1.so.sourcelist
# touch codegen/sector1.done
# date >disteval.done
# ln -f B1_1_1_1_1/disteval/B1_1_1_1_1.json disteval/B1_1_1_1_1.json
# make -C B1_1_1_1_1/ disteval.done
# make[1]: Leaving directory '/home/formswap/jasons/psd5kkjfwyb/sum/B1_1_0_1_1'
# ln -f B2_1_0_1_1/disteval/B2_1_0_1_1.json disteval/B2_1_0_1_1.json
# make[1]: Entering directory '/home/formswap/jasons/psd5kkjfwyb/sum/B1_1_1_1_1'
# make -C B2_1_0_1_1/ disteval.done
# cd codegen && /export/pc/bin/python3.10 '/users/tp/jasons/.local/lib/python3.10/site-packages/pySecDecContrib/bin/formwrapper' "/users/tp/jasons/.local/lib/python3.10/site-packages/pySecDecContrib/bin/form" -M -w1 -D optimizationLevel=4 -p '/users/tp/jasons/.local/lib/python3.10/site-packages/pySecDecContrib/lib' -D sectorID=4 '/users/tp/jasons/.local/lib/python3.10/site-packages/pySecDecContrib/lib/write_integrand.frm'
# make[1]: Entering directory '/home/formswap/jasons/psd5kkjfwyb/sum/B2_1_0_1_1'
# cd codegen && /export/pc/bin/python3.10 '/users/tp/jasons/.local/lib/python3.10/site-packages/pySecDecContrib/bin/formwrapper' "/users/tp/jasons/.local/lib/python3.10/site-packages/pySecDecContrib/bin/form" -M -w1 -D optimizationLevel=4 -p '/users/tp/jasons/.local/lib/python3.10/site-packages/pySecDecContrib/lib' -D sectorID=3 '/users/tp/jasons/.local/lib/python3.10/site-packages/pySecDecContrib/lib/write_integrand.frm'
# g++ -c -o distsrc/sector_3_0.o -fPIC -std=c++14 -O3 -funsafe-math-optimizations  distsrc/sector_3_0.cpp
# g++ -c -o distsrc/sector_2_0.o -fPIC -std=c++14 -O3 -funsafe-math-optimizations  distsrc/sector_2_0.cpp
# FORM 4.3.0 (Nov 12 2022, v4.3.0) 64-bits         Run: Thu Dec 21 14:29:39 2023
#     #-
#   0.28 sec out of 0.34 sec
# /export/pc/bin/python3.10 '/users/tp/jasons/.local/lib/python3.10/site-packages/pySecDecContrib/bin/export_sector' codegen/sector3.info ./
# touch codegen/sector3.done
# cd codegen && /export/pc/bin/python3.10 '/users/tp/jasons/.local/lib/python3.10/site-packages/pySecDecContrib/bin/formwrapper' "/users/tp/jasons/.local/lib/python3.10/site-packages/pySecDecContrib/bin/form" -M -w1 -D optimizationLevel=4 -p '/users/tp/jasons/.local/lib/python3.10/site-packages/pySecDecContrib/lib' -D sectorID=2 '/users/tp/jasons/.local/lib/python3.10/site-packages/pySecDecContrib/lib/write_integrand.frm'
# g++ -c -o distsrc/sector_1_0.o -fPIC -std=c++14 -O3 -funsafe-math-optimizations  distsrc/sector_1_0.cpp
# g++ -c -o distsrc/sector_2_0.o -fPIC -std=c++14 -O3 -funsafe-math-optimizations  distsrc/sector_2_0.cpp
# FORM 4.3.0 (Nov 12 2022, v4.3.0) 64-bits         Run: Thu Dec 21 14:29:39 2023
#     #-
#   0.61 sec out of 0.78 sec
# /export/pc/bin/python3.10 '/users/tp/jasons/.local/lib/python3.10/site-packages/pySecDecContrib/bin/export_sector' codegen/sector4.info ./
# FORM 4.3.0 (Nov 12 2022, v4.3.0) 64-bits         Run: Thu Dec 21 14:29:40 2023
#     #-
#   0.29 sec out of 0.31 sec
# /export/pc/bin/python3.10 '/users/tp/jasons/.local/lib/python3.10/site-packages/pySecDecContrib/bin/export_sector' codegen/sector2.info ./
# touch codegen/sector4.done
# cd codegen && /export/pc/bin/python3.10 '/users/tp/jasons/.local/lib/python3.10/site-packages/pySecDecContrib/bin/formwrapper' "/users/tp/jasons/.local/lib/python3.10/site-packages/pySecDecContrib/bin/form" -M -w1 -D optimizationLevel=4 -p '/users/tp/jasons/.local/lib/python3.10/site-packages/pySecDecContrib/lib' -D sectorID=3 '/users/tp/jasons/.local/lib/python3.10/site-packages/pySecDecContrib/lib/write_integrand.frm'
# touch codegen/sector2.done
# cd codegen && /export/pc/bin/python3.10 '/users/tp/jasons/.local/lib/python3.10/site-packages/pySecDecContrib/bin/formwrapper' "/users/tp/jasons/.local/lib/python3.10/site-packages/pySecDecContrib/bin/form" -M -w1 -D optimizationLevel=4 -p '/users/tp/jasons/.local/lib/python3.10/site-packages/pySecDecContrib/lib' -D sectorID=1 '/users/tp/jasons/.local/lib/python3.10/site-packages/pySecDecContrib/lib/write_integrand.frm'
# g++ -shared -o disteval/builtin.so distsrc/builtin.o
# FORM 4.3.0 (Nov 12 2022, v4.3.0) 64-bits         Run: Thu Dec 21 14:29:40 2023
#     #-
#   0.26 sec out of 0.34 sec
# /export/pc/bin/python3.10 '/users/tp/jasons/.local/lib/python3.10/site-packages/pySecDecContrib/bin/export_sector' codegen/sector1.info ./
# g++ -shared -o disteval/B1_1_1_1_0.so @disteval/B1_1_1_1_0.so.sourcelist
# g++ -c -o distsrc/sector_1_0.o -fPIC -std=c++14 -O3 -funsafe-math-optimizations  distsrc/sector_1_0.cpp
# touch codegen/sector1.done
# g++ -c -o distsrc/builtin.o -fPIC -std=c++14 -O3 -funsafe-math-optimizations  distsrc/builtin.cpp
# date >disteval.done
# make[1]: Leaving directory '/home/formswap/jasons/psd5kkjfwyb/sum/B1_1_1_1_0'
# ln -f B2_1_1_1_0/disteval/B2_1_1_1_0.json disteval/B2_1_1_1_0.json
# make -C B2_1_1_1_0/ disteval.done
# make[1]: Entering directory '/home/formswap/jasons/psd5kkjfwyb/sum/B2_1_1_1_0'
# cd codegen && /export/pc/bin/python3.10 '/users/tp/jasons/.local/lib/python3.10/site-packages/pySecDecContrib/bin/formwrapper' "/users/tp/jasons/.local/lib/python3.10/site-packages/pySecDecContrib/bin/form" -M -w1 -D optimizationLevel=4 -p '/users/tp/jasons/.local/lib/python3.10/site-packages/pySecDecContrib/lib' -D sectorID=3 '/users/tp/jasons/.local/lib/python3.10/site-packages/pySecDecContrib/lib/write_integrand.frm'
# FORM 4.3.0 (Nov 12 2022, v4.3.0) 64-bits         Run: Thu Dec 21 14:29:40 2023
#     #-
#   0.58 sec out of 0.66 sec
# /export/pc/bin/python3.10 '/users/tp/jasons/.local/lib/python3.10/site-packages/pySecDecContrib/bin/export_sector' codegen/sector3.info ./
# touch codegen/sector3.done
# cd codegen && /export/pc/bin/python3.10 '/users/tp/jasons/.local/lib/python3.10/site-packages/pySecDecContrib/bin/formwrapper' "/users/tp/jasons/.local/lib/python3.10/site-packages/pySecDecContrib/bin/form" -M -w1 -D optimizationLevel=4 -p '/users/tp/jasons/.local/lib/python3.10/site-packages/pySecDecContrib/lib' -D sectorID=2 '/users/tp/jasons/.local/lib/python3.10/site-packages/pySecDecContrib/lib/write_integrand.frm'
# g++ -shared -o disteval/builtin.so distsrc/builtin.o
# g++ -c -o distsrc/sector_3_0.o -fPIC -std=c++14 -O3 -funsafe-math-optimizations  distsrc/sector_3_0.cpp
# FORM 4.3.0 (Nov 12 2022, v4.3.0) 64-bits         Run: Thu Dec 21 14:29:41 2023
#     #-
#   0.28 sec out of 0.42 sec
# /export/pc/bin/python3.10 '/users/tp/jasons/.local/lib/python3.10/site-packages/pySecDecContrib/bin/export_sector' codegen/sector3.info ./
# g++ -shared -o disteval/B1_1_1_0_1.so @disteval/B1_1_1_0_1.so.sourcelist
# touch codegen/sector3.done
# date >disteval.done
# make[1]: Leaving directory '/home/formswap/jasons/psd5kkjfwyb/sum/B1_1_1_0_1'
# ln -f B2_1_1_1_1/disteval/B2_1_1_1_1.json disteval/B2_1_1_1_1.json
# make -C B2_1_1_1_1/ disteval.done
# make[1]: Entering directory '/home/formswap/jasons/psd5kkjfwyb/sum/B2_1_1_1_1'
# cd codegen && /export/pc/bin/python3.10 '/users/tp/jasons/.local/lib/python3.10/site-packages/pySecDecContrib/bin/formwrapper' "/users/tp/jasons/.local/lib/python3.10/site-packages/pySecDecContrib/bin/form" -M -w1 -D optimizationLevel=4 -p '/users/tp/jasons/.local/lib/python3.10/site-packages/pySecDecContrib/lib' -D sectorID=4 '/users/tp/jasons/.local/lib/python3.10/site-packages/pySecDecContrib/lib/write_integrand.frm'
# cd codegen && /export/pc/bin/python3.10 '/users/tp/jasons/.local/lib/python3.10/site-packages/pySecDecContrib/bin/formwrapper' "/users/tp/jasons/.local/lib/python3.10/site-packages/pySecDecContrib/bin/form" -M -w1 -D optimizationLevel=4 -p '/users/tp/jasons/.local/lib/python3.10/site-packages/pySecDecContrib/lib' -D sectorID=2 '/users/tp/jasons/.local/lib/python3.10/site-packages/pySecDecContrib/lib/write_integrand.frm'
# FORM 4.3.0 (Nov 12 2022, v4.3.0) 64-bits         Run: Thu Dec 21 14:29:41 2023
#     #-
#   0.58 sec out of 0.72 sec
# /export/pc/bin/python3.10 '/users/tp/jasons/.local/lib/python3.10/site-packages/pySecDecContrib/bin/export_sector' codegen/sector2.info ./
# touch codegen/sector2.done
# cd codegen && /export/pc/bin/python3.10 '/users/tp/jasons/.local/lib/python3.10/site-packages/pySecDecContrib/bin/formwrapper' "/users/tp/jasons/.local/lib/python3.10/site-packages/pySecDecContrib/bin/form" -M -w1 -D optimizationLevel=4 -p '/users/tp/jasons/.local/lib/python3.10/site-packages/pySecDecContrib/lib' -D sectorID=1 '/users/tp/jasons/.local/lib/python3.10/site-packages/pySecDecContrib/lib/write_integrand.frm'
# g++ -c -o distsrc/sector_2_0.o -fPIC -std=c++14 -O3 -funsafe-math-optimizations  distsrc/sector_2_0.cpp
# FORM 4.3.0 (Nov 12 2022, v4.3.0) 64-bits         Run: Thu Dec 21 14:29:42 2023
#     #-
#   0.29 sec out of 0.37 sec
# /export/pc/bin/python3.10 '/users/tp/jasons/.local/lib/python3.10/site-packages/pySecDecContrib/bin/export_sector' codegen/sector2.info ./
# touch codegen/sector2.done
# cd codegen && /export/pc/bin/python3.10 '/users/tp/jasons/.local/lib/python3.10/site-packages/pySecDecContrib/bin/formwrapper' "/users/tp/jasons/.local/lib/python3.10/site-packages/pySecDecContrib/bin/form" -M -w1 -D optimizationLevel=4 -p '/users/tp/jasons/.local/lib/python3.10/site-packages/pySecDecContrib/lib' -D sectorID=1 '/users/tp/jasons/.local/lib/python3.10/site-packages/pySecDecContrib/lib/write_integrand.frm'
# FORM 4.3.0 (Nov 12 2022, v4.3.0) 64-bits         Run: Thu Dec 21 14:29:42 2023
#     #-
#   0.58 sec out of 0.86 sec
# /export/pc/bin/python3.10 '/users/tp/jasons/.local/lib/python3.10/site-packages/pySecDecContrib/bin/export_sector' codegen/sector4.info ./
# g++ -c -o distsrc/sector_1_0.o -fPIC -std=c++14 -O3 -funsafe-math-optimizations  distsrc/sector_1_0.cpp
# touch codegen/sector4.done
# cd codegen && /export/pc/bin/python3.10 '/users/tp/jasons/.local/lib/python3.10/site-packages/pySecDecContrib/bin/formwrapper' "/users/tp/jasons/.local/lib/python3.10/site-packages/pySecDecContrib/bin/form" -M -w1 -D optimizationLevel=4 -p '/users/tp/jasons/.local/lib/python3.10/site-packages/pySecDecContrib/lib' -D sectorID=3 '/users/tp/jasons/.local/lib/python3.10/site-packages/pySecDecContrib/lib/write_integrand.frm'
# FORM 4.3.0 (Nov 12 2022, v4.3.0) 64-bits         Run: Thu Dec 21 14:29:42 2023
#     #-
#   0.26 sec out of 0.38 sec
# /export/pc/bin/python3.10 '/users/tp/jasons/.local/lib/python3.10/site-packages/pySecDecContrib/bin/export_sector' codegen/sector1.info ./
# FORM 4.3.0 (Nov 12 2022, v4.3.0) 64-bits         Run: Thu Dec 21 14:29:42 2023
#     #-
#   0.55 sec out of 0.65 sec
# /export/pc/bin/python3.10 '/users/tp/jasons/.local/lib/python3.10/site-packages/pySecDecContrib/bin/export_sector' codegen/sector1.info ./
# touch codegen/sector1.done
# g++ -c -o distsrc/builtin.o -fPIC -std=c++14 -O3 -funsafe-math-optimizations  distsrc/builtin.cpp
# touch codegen/sector1.done
# g++ -c -o distsrc/builtin.o -fPIC -std=c++14 -O3 -funsafe-math-optimizations  distsrc/builtin.cpp
# g++ -c -o distsrc/sector_4_0.o -fPIC -std=c++14 -O3 -funsafe-math-optimizations  distsrc/sector_4_0.cpp
# g++ -c -o distsrc/sector_3_0.o -fPIC -std=c++14 -O3 -funsafe-math-optimizations  distsrc/sector_3_0.cpp
# g++ -shared -o disteval/builtin.so distsrc/builtin.o
# g++ -shared -o disteval/B2_1_0_1_1.so @disteval/B2_1_0_1_1.so.sourcelist
# FORM 4.3.0 (Nov 12 2022, v4.3.0) 64-bits         Run: Thu Dec 21 14:29:43 2023
#     #-
#   0.58 sec out of 0.86 sec
# /export/pc/bin/python3.10 '/users/tp/jasons/.local/lib/python3.10/site-packages/pySecDecContrib/bin/export_sector' codegen/sector3.info ./
# touch codegen/sector3.done
# date >disteval.done
# cd codegen && /export/pc/bin/python3.10 '/users/tp/jasons/.local/lib/python3.10/site-packages/pySecDecContrib/bin/formwrapper' "/users/tp/jasons/.local/lib/python3.10/site-packages/pySecDecContrib/bin/form" -M -w1 -D optimizationLevel=4 -p '/users/tp/jasons/.local/lib/python3.10/site-packages/pySecDecContrib/lib' -D sectorID=2 '/users/tp/jasons/.local/lib/python3.10/site-packages/pySecDecContrib/lib/write_integrand.frm'
# make[1]: Leaving directory '/home/formswap/jasons/psd5kkjfwyb/sum/B2_1_0_1_1'
# ln -f B3_1_1_1_1/disteval/B3_1_1_1_1.json disteval/B3_1_1_1_1.json
# make -C B3_1_1_1_1/ disteval.done
# make[1]: Entering directory '/home/formswap/jasons/psd5kkjfwyb/sum/B3_1_1_1_1'
# cd codegen && /export/pc/bin/python3.10 '/users/tp/jasons/.local/lib/python3.10/site-packages/pySecDecContrib/bin/formwrapper' "/users/tp/jasons/.local/lib/python3.10/site-packages/pySecDecContrib/bin/form" -M -w1 -D optimizationLevel=4 -p '/users/tp/jasons/.local/lib/python3.10/site-packages/pySecDecContrib/lib' -D sectorID=4 '/users/tp/jasons/.local/lib/python3.10/site-packages/pySecDecContrib/lib/write_integrand.frm'
# g++ -c -o distsrc/sector_2_0.o -fPIC -std=c++14 -O3 -funsafe-math-optimizations  distsrc/sector_2_0.cpp
# g++ -c -o distsrc/sector_3_0.o -fPIC -std=c++14 -O3 -funsafe-math-optimizations  distsrc/sector_3_0.cpp
# g++ -c -o distsrc/sector_1_0.o -fPIC -std=c++14 -O3 -funsafe-math-optimizations  distsrc/sector_1_0.cpp
# FORM 4.3.0 (Nov 12 2022, v4.3.0) 64-bits         Run: Thu Dec 21 14:29:44 2023
#     #-
#   0.62 sec out of 0.75 sec
# /export/pc/bin/python3.10 '/users/tp/jasons/.local/lib/python3.10/site-packages/pySecDecContrib/bin/export_sector' codegen/sector2.info ./
# touch codegen/sector2.done
# FORM 4.3.0 (Nov 12 2022, v4.3.0) 64-bits         Run: Thu Dec 21 14:29:44 2023
#     #-
#   0.59 sec out of 0.91 sec
# cd codegen && /export/pc/bin/python3.10 '/users/tp/jasons/.local/lib/python3.10/site-packages/pySecDecContrib/bin/formwrapper' "/users/tp/jasons/.local/lib/python3.10/site-packages/pySecDecContrib/bin/form" -M -w1 -D optimizationLevel=4 -p '/users/tp/jasons/.local/lib/python3.10/site-packages/pySecDecContrib/lib' -D sectorID=1 '/users/tp/jasons/.local/lib/python3.10/site-packages/pySecDecContrib/lib/write_integrand.frm'
# /export/pc/bin/python3.10 '/users/tp/jasons/.local/lib/python3.10/site-packages/pySecDecContrib/bin/export_sector' codegen/sector4.info ./
# touch codegen/sector4.done
# cd codegen && /export/pc/bin/python3.10 '/users/tp/jasons/.local/lib/python3.10/site-packages/pySecDecContrib/bin/formwrapper' "/users/tp/jasons/.local/lib/python3.10/site-packages/pySecDecContrib/bin/form" -M -w1 -D optimizationLevel=4 -p '/users/tp/jasons/.local/lib/python3.10/site-packages/pySecDecContrib/lib' -D sectorID=3 '/users/tp/jasons/.local/lib/python3.10/site-packages/pySecDecContrib/lib/write_integrand.frm'
# g++ -c -o distsrc/sector_2_0.o -fPIC -std=c++14 -O3 -funsafe-math-optimizations  distsrc/sector_2_0.cpp
# g++ -shared -o disteval/builtin.so distsrc/builtin.o
# g++ -shared -o disteval/B2_1_1_1_0.so @disteval/B2_1_1_1_0.so.sourcelist
# date >disteval.done
# make[1]: Leaving directory '/home/formswap/jasons/psd5kkjfwyb/sum/B2_1_1_1_0'
# ln -f B1_0_1_1_0/disteval/builtin.so disteval/builtin.so
# ln -f B1_0_1_1_0/disteval/B1_0_1_1_0.so disteval/B1_0_1_1_0.so
# ln -f B1_0_1_1_1/disteval/B1_0_1_1_1.so disteval/B1_0_1_1_1.so
# ln -f B1_1_0_1_1/disteval/B1_1_0_1_1.so disteval/B1_1_0_1_1.so
# ln -f B1_1_1_0_1/disteval/B1_1_1_0_1.so disteval/B1_1_1_0_1.so
# ln -f B1_1_1_1_0/disteval/B1_1_1_1_0.so disteval/B1_1_1_1_0.so
# ln -f B2_1_0_1_1/disteval/B2_1_0_1_1.so disteval/B2_1_0_1_1.so
# ln -f B2_1_1_1_0/disteval/B2_1_1_1_0.so disteval/B2_1_1_1_0.so
# g++ -c -o distsrc/sector_1_0.o -fPIC -std=c++14 -O3 -funsafe-math-optimizations  distsrc/sector_1_0.cpp
# FORM 4.3.0 (Nov 12 2022, v4.3.0) 64-bits         Run: Thu Dec 21 14:29:45 2023
#     #-
#   0.59 sec out of 0.69 sec
# /export/pc/bin/python3.10 '/users/tp/jasons/.local/lib/python3.10/site-packages/pySecDecContrib/bin/export_sector' codegen/sector3.info ./
# g++ -shared -o disteval/builtin.so distsrc/builtin.o
# cd codegen && /export/pc/bin/python3.10 '/users/tp/jasons/.local/lib/python3.10/site-packages/pySecDecContrib/bin/formwrapper' "/users/tp/jasons/.local/lib/python3.10/site-packages/pySecDecContrib/bin/form" -M -w1 -D optimizationLevel=4 -p '/users/tp/jasons/.local/lib/python3.10/site-packages/pySecDecContrib/lib' -D sectorID=2 '/users/tp/jasons/.local/lib/python3.10/site-packages/pySecDecContrib/lib/write_integrand.frm'
# touch codegen/sector3.done
# cd codegen && /export/pc/bin/python3.10 '/users/tp/jasons/.local/lib/python3.10/site-packages/pySecDecContrib/bin/formwrapper' "/users/tp/jasons/.local/lib/python3.10/site-packages/pySecDecContrib/bin/form" -M -w1 -D optimizationLevel=4 -p '/users/tp/jasons/.local/lib/python3.10/site-packages/pySecDecContrib/lib' -D sectorID=1 '/users/tp/jasons/.local/lib/python3.10/site-packages/pySecDecContrib/lib/write_integrand.frm'
# FORM 4.3.0 (Nov 12 2022, v4.3.0) 64-bits         Run: Thu Dec 21 14:29:45 2023
#     #-
#   0.56 sec out of 0.88 sec
# /export/pc/bin/python3.10 '/users/tp/jasons/.local/lib/python3.10/site-packages/pySecDecContrib/bin/export_sector' codegen/sector1.info ./
# touch codegen/sector1.done
# g++ -c -o distsrc/builtin.o -fPIC -std=c++14 -O3 -funsafe-math-optimizations  distsrc/builtin.cpp
# g++ -shared -o disteval/B1_1_1_1_1.so @disteval/B1_1_1_1_1.so.sourcelist
# g++ -c -o distsrc/sector_4_0.o -fPIC -std=c++14 -O3 -funsafe-math-optimizations  distsrc/sector_4_0.cpp
# date >disteval.done
# make[1]: Leaving directory '/home/formswap/jasons/psd5kkjfwyb/sum/B1_1_1_1_1'
# ln -f B1_1_1_1_1/disteval/B1_1_1_1_1.so disteval/B1_1_1_1_1.so
# g++ -c -o distsrc/builtin.o -fPIC -std=c++14 -O3 -funsafe-math-optimizations  distsrc/builtin.cpp
# FORM 4.3.0 (Nov 12 2022, v4.3.0) 64-bits         Run: Thu Dec 21 14:29:46 2023
#     #-
#   0.60 sec out of 0.93 sec
# /export/pc/bin/python3.10 '/users/tp/jasons/.local/lib/python3.10/site-packages/pySecDecContrib/bin/export_sector' codegen/sector2.info ./
# FORM 4.3.0 (Nov 12 2022, v4.3.0) 64-bits         Run: Thu Dec 21 14:29:46 2023
#     #-
#   0.60 sec out of 0.88 sec
# /export/pc/bin/python3.10 '/users/tp/jasons/.local/lib/python3.10/site-packages/pySecDecContrib/bin/export_sector' codegen/sector1.info ./
# touch codegen/sector1.done
# g++ -c -o distsrc/sector_4_0.o -fPIC -std=c++14 -O3 -funsafe-math-optimizations  distsrc/sector_4_0.cpp
# touch codegen/sector2.done
# g++ -c -o distsrc/sector_3_0.o -fPIC -std=c++14 -O3 -funsafe-math-optimizations  distsrc/sector_3_0.cpp
# g++ -c -o distsrc/sector_2_0.o -fPIC -std=c++14 -O3 -funsafe-math-optimizations  distsrc/sector_2_0.cpp
# g++ -c -o distsrc/sector_3_0.o -fPIC -std=c++14 -O3 -funsafe-math-optimizations  distsrc/sector_3_0.cpp
# g++ -c -o distsrc/sector_1_0.o -fPIC -std=c++14 -O3 -funsafe-math-optimizations  distsrc/sector_1_0.cpp
# g++ -shared -o disteval/builtin.so distsrc/builtin.o
# g++ -c -o distsrc/sector_2_0.o -fPIC -std=c++14 -O3 -funsafe-math-optimizations  distsrc/sector_2_0.cpp
# g++ -c -o distsrc/sector_1_0.o -fPIC -std=c++14 -O3 -funsafe-math-optimizations  distsrc/sector_1_0.cpp
# g++ -shared -o disteval/builtin.so distsrc/builtin.o
# g++ -shared -o disteval/B3_1_1_1_1.so @disteval/B3_1_1_1_1.so.sourcelist
# date >disteval.done
# make[1]: Leaving directory '/home/formswap/jasons/psd5kkjfwyb/sum/B3_1_1_1_1'
# ln -f B3_1_1_1_1/disteval/B3_1_1_1_1.so disteval/B3_1_1_1_1.so
# g++ -shared -o disteval/B2_1_1_1_1.so @disteval/B2_1_1_1_1.so.sourcelist
# date >disteval.done
# make[1]: Leaving directory '/home/formswap/jasons/psd5kkjfwyb/sum/B2_1_1_1_1'
# ln -f B2_1_1_1_1/disteval/B2_1_1_1_1.so disteval/B2_1_1_1_1.so
# date >disteval.done
# make: Leaving directory '/home/formswap/jasons/psd5kkjfwyb/sum'
